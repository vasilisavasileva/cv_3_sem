# %%
import sys

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Задание 1: работа с цветовым пространством HSV. На практике познакомились с преимуществами использования пространства HSV. Если кратко, то с помощью этой модели легче описывать цвет, который мы хотим получить. Поскольку здесь мы оперируем понятиями H = Hue = оттенок, S = Saturation = насыщенность, V = Value = яркость. Используя модель HSV попробуйте еще раз выполнить задание по превращению "starry_night" в "starry_day" (из дз №1)

# %%
img = cv.imread("starry_night.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img_mod = img
blue_channel = img_mod[:, :, 2]
green_channel = img_mod[:, :, 1]
red_channel = img_mod[:, :, 0]
img_mod[:, :, 1] = red_channel/1.2
img_mod[:, :, 0] = green_channel
img_mod[:, :, 2] = blue_channel/1.4
cv.convertScaleAbs(img, img_mod, 1.8, 10)
plt.imshow(img_mod)

# %%
img_hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
hue_channel = img_hsv[:, :, 0]
sat_channel = img_hsv[:, :, 1]
val_channel = img_hsv[:, :, 2]
img_hsv[:, :, 0] = hue_channel/1.4
img_hsv[:, :, 1] = sat_channel/1.2
# img_hsv[:, :, 2] = val_channel
image_final = cv.cvtColor(img_hsv, cv.COLOR_HSV2RGB)
plt.imshow(image_final)

# %% [markdown]
# ### Задание 2: На занятии мы разобрали несколько подходов для того, чтобы "размыть" изображение. Для этого мы использовали фильтры, представленные различными матрицами (ядрами). Вопрос - как нам решить обратную задачу? Т.е., имея размытое изображение, как сделать его более четким? Попробуйте подобрать матрицу, которая может это сделать.

# %%
img_blr = cv.imread("starry_night.jpg")
img_blr = cv.cvtColor(img_blr, cv.COLOR_BGR2RGB)
plt.imshow(img_blr)

# %%
img_blr = cv.GaussianBlur(img_blr, (21, 21), 0)
plt.imshow(img_blr)

# %% [markdown]
# ## 3x3

# %%
kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
img_rvs = cv.filter2D(img_blr, -1, kernel)
plt.imshow(img_rvs)

# %% [markdown]
# ## 5x5

# %%
filter = np.array([[0,0,-1,0,0],[0,-1,-2,-1,0],[-1,-2,16,-2,-1],[0,-1,-2,-1,0],[0,0,-1,0,0]])
img_rvs = cv.filter2D(img_blr, -1, kernel)
plt.imshow(img_blr)
